# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pypsdm import GridWithResults


# csv files in resources are tracked via git lfs
# to retrieve them make sure you have git lfs installed
grid_path = "../resources/simbench/grid/"
results_path = "../resources/simbench/results/rawOutputData/"

gwr = GridWithResults.from_csv(grid_path, results_path)
# Out:
# 2024-05-03 13:51:26.504 | INFO     | pypsdm.models.gwr:from_csv:275 - Reading grid from ../resources/simbench/grid/
# 2024-05-03 13:51:29.626 | INFO     | pypsdm.models.gwr:from_csv:287 - Reading results from ../resources/simbench/results/rawOutputData/

# %%
nodes = gwr.nodes_res.v_mag()
nodes.head()
# Out:
#                      MV3.101 Bus 23  MV3.101 Bus 114  MV3.101 Bus 78  \
# time
# 2016-01-01 01:00:00        1.030701         1.026366        1.030997
# 2016-01-01 02:00:00        1.032337         1.028726        1.032560
# 2016-01-01 03:00:00        1.031248         1.026735        1.031411
# 2016-01-01 04:00:00        1.031595         1.027606        1.031843
# 2016-01-01 05:00:00        1.029550         1.024716        1.029838
#
#                      MV3.101 Bus 70  MV3.101 Bus 74  MV3.101 Bus 77  \
# time
# 2016-01-01 01:00:00        1.023754        1.022749        1.031425
# 2016-01-01 02:00:00        1.026038        1.025147        1.032923
# 2016-01-01 03:00:00        1.023885        1.022907        1.031852
# 2016-01-01 04:00:00        1.024844        1.023846        1.032237
# 2016-01-01 05:00:00        1.021376        1.020256        1.030328
#
#                      MV3.101 Bus 56  MV3.101 Bus 42  MV3.101 Bus 130  \
# time
# 2016-01-01 01:00:00        1.029841        1.031178         1.029625
# 2016-01-01 02:00:00        1.031628        1.032707         1.031425
# 2016-01-01 03:00:00        1.030388        1.031611         1.030293
# 2016-01-01 04:00:00        1.030876        1.032035         1.030667
# 2016-01-01 05:00:00        1.028614        1.030042         1.028405
#
#                      MV3.101 Bus 108  ...  MV3.101 Bus 98  MV3.101 Bus 117  \
# time                                  ...
# 2016-01-01 01:00:00         1.029239  ...        1.029864         1.025949
# 2016-01-01 02:00:00         1.031103  ...        1.031613         1.028402
# 2016-01-01 03:00:00         1.029632  ...        1.030380         1.026346
# 2016-01-01 04:00:00         1.030203  ...        1.030849         1.027237
# 2016-01-01 05:00:00         1.027881  ...        1.028705         1.024273
#
#                      MV3.101 Bus 103  MV3.101 Bus 47  MV3.101 Bus 99  \
# time
# 2016-01-01 01:00:00         1.028761        1.029669        1.029472
# 2016-01-01 02:00:00         1.030758        1.031438        1.031312
# 2016-01-01 03:00:00         1.029313        1.030216        1.029998
# 2016-01-01 04:00:00         1.029909        1.030748        1.030515
# 2016-01-01 05:00:00         1.027517        1.028449        1.028267
#
#                      MV3.101 Bus 129  MV3.101 Bus 135_1  MV3.101 Bus 115  \
# time
# 2016-01-01 01:00:00         1.029025           1.029026         1.026155
# 2016-01-01 02:00:00         1.030974           1.030975         1.028557
# 2016-01-01 03:00:00         1.029807           1.029808         1.026534
# 2016-01-01 04:00:00         1.030125           1.030126         1.027417
# 2016-01-01 05:00:00         1.027759           1.027759         1.024495
#
#                      MV3.101 Bus 35  MV3.101 Bus 45
# time
# 2016-01-01 01:00:00        1.028715        1.030045
# 2016-01-01 02:00:00        1.030879        1.031746
# 2016-01-01 03:00:00        1.029679        1.030560
# 2016-01-01 04:00:00        1.030013        1.031063
# 2016-01-01 05:00:00        1.027686        1.028868
#
# [5 rows x 147 columns]
